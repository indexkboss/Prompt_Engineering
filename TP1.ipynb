# %%
print("hi")#shift+enter pour exec
# Out:
# hi

# %%
#la tokenisation c'est la premiere etape de la NLP 
#c'est le processus de diviser un texte en unités plus petites appelées tokens.
#ces tokens peuvent être des mots, phrases, des caractères.., en fonction de la méthode de tokenisation utilisée. 

#c'est une étape cruciale, elle permet de préparer le texte pour les étapes suivantes telles que: 
#l'analyse syntaxique, la reconnaissance d'entités nommées, et la modélisation du langage.

#Il existe plusieurs méthodes de tokenisation

# %%
#on veut savoir le nb de tokens dans un prompt pour ?? on utilise biblio tiktoken:
import tiktoken

# %%
#methode 1: specifier le model pour lequel on veut connaitre le tokennizer
tokennizer = tiktoken.encoding_for_model("gpt-4o")
print(tokennizer.name)#affiche le nom du tokennizer utilisé pour ce model
# Out:
# o200k_base

# %%
#methode 2 : on done le nom directe de loutil de tokenisation du modele
tokennizer = tiktoken.get_encoding("o200k_base")

# %%
prompt = "au clair de la lune, mon ami pierrot, prête-moi ta plume pour écrire un mot"

# %%
tokens = tokennizer.encode(prompt)

# %%
print(tokens) #affiche la liste des tokens, chaque token est représenté par un entier.
# Out:
# [753, 71396, 334, 557, 174383, 11, 1767, 39348, 18134, 8150, 11, 136343, 119003, 2868, 155679, 1930, 118651, 537, 3598]

# %%
print(len(tokens))
# Out:
# 19

# %%
print("1:\n")
for token in tokens:
    print(tokennizer.decode_single_token_bytes(token))#format bytes (brut)
    # Prend UN SEUL token → retourne des bytes (brut), pas une chaîne
print("2:\n")
for token in tokens:
    print((tokennizer.decode_single_token_bytes(token).decode("utf-8")),end="|") #format texte, end pour separer par |

print("3:\n")
print(tokennizer.decode(tokens))
# Prend une liste de tokens → retourne une chaîne de caractères (str)
# Out:
# 1:
#
# b'au'
# b' clair'
# b' de'
# b' la'
# b' lune'
# b','
# b' mon'
# b' ami'
# b' pier'
# b'rot'
# b','
# b' pr\xc3\xaate'
# b'-moi'
# b' ta'
# b' plume'
# b' pour'
# b' \xc3\xa9crire'
# b' un'
# b' mot'
# 2:
#
# au| clair| de| la| lune|,| mon| ami| pier|rot|,| prête|-moi| ta| plume| pour| écrire| un| mot|3:
#
# au clair de la lune, mon ami pierrot, prête-moi ta plume pour écrire un mot

# %%
#on a besoin de connaitre le nb de tokens 
#cette fonction :
def tokens_count(prompt:str, model:str="o200k_base"):#o200k_base est le tokennizer par defaut 
    tokennizer = tiktoken.get_encoding(model)#on récupère le "tokenizer" du modèle choisi
    tokens = tokennizer.encode(prompt)#le decoupement du prompt en tokens
    return len(tokens)

# %%
print(tokens_count(prompt))
# Out:
# 19

# %% [markdown]
# **Interagir avec un LLM OpenAI (need api key):**

# %%
#uv add openai, langchain, langchain-openai, ollama, langchain-openai, langchain-groq.
from langchain_openai import ChatOpenAI

#import os #pour creer une variable d'environnement pour stocker la clé API de manière sécurisée
# os.environ['OPENAI_API_KEY'] = "..."

from dotenv.ipython import load_dotenv
load_dotenv(override=True) #pour charger les variables d'environnement à partir du fichier .env
# Out:
# True

# %%
llm1 = ChatOpenAI(
    model="openai/gpt-oss-20b:free",
    temperature=0.9,
#proche de 1 : plus creatif, a chaque fois reponse diff, 
# proche de 0 : plus deterministe
    base_url="https://openrouter.ai/api/v1"#car we're using openRouter
)

# %%
resp = llm1.invoke(input=[
    {"role":"system","content":"you are a helpful assistant"},
    {"role":"user","content":"what's an ai agent?"}
])
#input = sys message,fewShot examples, user input.

# %%
print(resp.content)
# Out:
# ### In a nutshell
#
# An **AI agent** is a software or hardware system that **perceives its environment, deliberates about what to do, and then acts in that environment** in order to achieve some goal or set of goals. It’s the “actor” in the classic perception‑action loop that drives much of artificial intelligence research and practice.
#
# ---
#
# ## 1. Core components of an AI agent
#
# | Component | What it does | Typical technologies |
# |-----------|--------------|----------------------|
# | **Sensors / Perception** | Gathers data from the environment (e.g., camera images, microphone audio, sensor readings). | Computer vision, NLP, signal‑processing, IoT sensor interfaces. |
# | **World Model / State Estimation** | Builds an internal representation of the environment’s current state, often simplifying or predicting future states. | Probabilistic models, deep learning embeddings, physics engines. |
# | **Decision‑Making / Planning** | Chooses a course of action that moves the agent toward its goal(s). | Reinforcement learning, symbolic planners, rule‑based systems, Bayesian reasoning. |
# | **Actuators / Output** | Executes actions that influence the environment (e.g., moving a robot arm, sending a text message, adjusting a thermostat). | Motor controllers, network protocols, user interfaces. |
# | **Goal / Reward Specification** | Provides the objective that the agent tries to achieve. | Explicit reward functions, utility scores, human‑supplied goals. |
# | **Learning / Adaptation** | Improves its models or policy over time based on experience. | Supervised / unsupervised learning, reinforcement learning, online adaptation. |
#
# ---
#
# ## 2. Types / Taxonomies
#
# | Category | Example | Typical domain |
# |----------|---------|----------------|
# | **Reactive agents** | Simple IF‑THEN rules, subsumption architecture | Real‑time robotics, game AI |
# | **Deliberative agents** | Full planning with search (e.g., STRIPS planners) | Logistics, strategy games |
# | **Hybrid agents** | Combine reactive and deliberative layers | Autonomous driving, smart homes |
# | **Learning agents** | RL agents, evolutionary agents | Game playing, recommendation systems |
# | **Multi‑agent systems** | Teams of agents collaborating or competing | Swarm robotics, distributed AI |
#
# ---
#
# ## 3. Formal definition (from Russell & Norvig)
#
# > **An agent is an autonomous entity that perceives its environment and acts upon it in order to achieve its goals.**
#
# Key words:
# - **Autonomous** – can operate without continuous human oversight.
# - **Perceives** – relies on sensors, not just a pre‑loaded dataset.
# - **Acts** – changes the environment or its internal state.
# - **Goals** – there is a notion of success/failure.
#
# ---
#
# ## 4. Real‑world examples
#
# | Agent | What it does | How it works |
# |-------|--------------|--------------|
# | **Siri / Alexa** | Voice‑activated personal assistants | NLP + dialogue management + cloud APIs |
# | **Tesla Autopilot** | Semi‑autonomous driving | Deep learning perception + rule‑based planner + CAN bus actuators |
# | **AlphaGo** | Plays Go at superhuman level | Deep neural nets + Monte‑Carlo Tree Search |
# | **Warehouse robots** | Move goods | SLAM, path planning, ROS-based control |
# | **Recommendation bots** | Suggest movies or products | Collaborative filtering + bandit algorithms |
#
# ---
#
# ## 5. Why “agent” matters
#
# - **Modularity**: The perception, reasoning, and actuation layers can be swapped or upgraded independently.
# - **Scalability**: Many agents can be combined into a system (e.g., a fleet of delivery drones).
# - **Deployment**: The same agent architecture can be deployed on different platforms (cloud, edge, embedded).
# - **Safety & Ethics**: By specifying goals and constraints explicitly, we can reason about agent behavior.
#
# ---
#
# ## 6. Common misconceptions
#
# | Misconception | Reality |
# |---------------|---------|
# | An AI agent is just a “smart chatbot.” | A chatbot can be an agent, but many agents have physical or non‑linguistic roles. |
# | AI agents are fully autonomous and need no human input. | Most real‑world agents operate under human‑defined goals, constraints, or supervisory controls. |
# | All agents are learning. | Some agents, especially in safety‑critical domains, rely on robust, hand‑crafted rules and do not learn during operation. |
#
# ---
#
# ## 7. Building an AI Agent – Quick Checklist
#
# 1. **Define the goal** (reward function, success criteria).
# 2. **Choose sensors** appropriate for the environment.
# 3. **Model the world** (probabilistic state estimator or learned representation).
# 4. **Select a decision rule**: rule‑based, planner, RL policy, etc.
# 5. **Implement actuators** that can affect the environment.
# 6. **Add learning or adaptation** if improvement over time is required.
# 7. **Test** in simulation before real‑world deployment.
# 8. **Monitor & update**: keep the agent honest and safe.
#
# ---
#
# ### Bottom line
#
# An AI agent is a *complete, goal‑driven system* that can observe, decide, and act—often learning from experience—to accomplish tasks in a dynamic environment. Whether it’s a software bot on your phone or a self‑driving car, the agent framework helps you think about the whole pipeline from perception to action.

# %%
from IPython.display import Markdown

# %%
print(display(Markdown(resp.content)))
# Out:
# ### In a nutshell
#
# An **AI agent** is a software or hardware system that **perceives its environment, deliberates about what to do, and then acts in that environment** in order to achieve some goal or set of goals. It’s the “actor” in the classic perception‑action loop that drives much of artificial intelligence research and practice.
#
# ---
#
# ## 1. Core components of an AI agent
#
# | Component | What it does | Typical technologies |
# |-----------|--------------|----------------------|
# | **Sensors / Perception** | Gathers data from the environment (e.g., camera images, microphone audio, sensor readings). | Computer vision, NLP, signal‑processing, IoT sensor interfaces. |
# | **World Model / State Estimation** | Builds an internal representation of the environment’s current state, often simplifying or predicting future states. | Probabilistic models, deep learning embeddings, physics engines. |
# | **Decision‑Making / Planning** | Chooses a course of action that moves the agent toward its goal(s). | Reinforcement learning, symbolic planners, rule‑based systems, Bayesian reasoning. |
# | **Actuators / Output** | Executes actions that influence the environment (e.g., moving a robot arm, sending a text message, adjusting a thermostat). | Motor controllers, network protocols, user interfaces. |
# | **Goal / Reward Specification** | Provides the objective that the agent tries to achieve. | Explicit reward functions, utility scores, human‑supplied goals. |
# | **Learning / Adaptation** | Improves its models or policy over time based on experience. | Supervised / unsupervised learning, reinforcement learning, online adaptation. |
#
# ---
#
# ## 2. Types / Taxonomies
#
# | Category | Example | Typical domain |
# |----------|---------|----------------|
# | **Reactive agents** | Simple IF‑THEN rules, subsumption architecture | Real‑time robotics, game AI |
# | **Deliberative agents** | Full planning with search (e.g., STRIPS planners) | Logistics, strategy games |
# | **Hybrid agents** | Combine reactive and deliberative layers | Autonomous driving, smart homes |
# | **Learning agents** | RL agents, evolutionary agents | Game playing, recommendation systems |
# | **Multi‑agent systems** | Teams of agents collaborating or competing | Swarm robotics, distributed AI |
#
# ---
#
# ## 3. Formal definition (from Russell & Norvig)
#
# > **An agent is an autonomous entity that perceives its environment and acts upon it in order to achieve its goals.**
#
# Key words:
# - **Autonomous** – can operate without continuous human oversight.
# - **Perceives** – relies on sensors, not just a pre‑loaded dataset.
# - **Acts** – changes the environment or its internal state.
# - **Goals** – there is a notion of success/failure.
#
# ---
#
# ## 4. Real‑world examples
#
# | Agent | What it does | How it works |
# |-------|--------------|--------------|
# | **Siri / Alexa** | Voice‑activated personal assistants | NLP + dialogue management + cloud APIs |
# | **Tesla Autopilot** | Semi‑autonomous driving | Deep learning perception + rule‑based planner + CAN bus actuators |
# | **AlphaGo** | Plays Go at superhuman level | Deep neural nets + Monte‑Carlo Tree Search |
# | **Warehouse robots** | Move goods | SLAM, path planning, ROS-based control |
# | **Recommendation bots** | Suggest movies or products | Collaborative filtering + bandit algorithms |
#
# ---
#
# ## 5. Why “agent” matters
#
# - **Modularity**: The perception, reasoning, and actuation layers can be swapped or upgraded independently.
# - **Scalability**: Many agents can be combined into a system (e.g., a fleet of delivery drones).
# - **Deployment**: The same agent architecture can be deployed on different platforms (cloud, edge, embedded).
# - **Safety & Ethics**: By specifying goals and constraints explicitly, we can reason about agent behavior.
#
# ---
#
# ## 6. Common misconceptions
#
# | Misconception | Reality |
# |---------------|---------|
# | An AI agent is just a “smart chatbot.” | A chatbot can be an agent, but many agents have physical or non‑linguistic roles. |
# | AI agents are fully autonomous and need no human input. | Most real‑world agents operate under human‑defined goals, constraints, or supervisory controls. |
# | All agents are learning. | Some agents, especially in safety‑critical domains, rely on robust, hand‑crafted rules and do not learn during operation. |
#
# ---
#
# ## 7. Building an AI Agent – Quick Checklist
#
# 1. **Define the goal** (reward function, success criteria).
# 2. **Choose sensors** appropriate for the environment.
# 3. **Model the world** (probabilistic state estimator or learned representation).
# 4. **Select a decision rule**: rule‑based, planner, RL policy, etc.
# 5. **Implement actuators** that can affect the environment.
# 6. **Add learning or adaptation** if improvement over time is required.
# 7. **Test** in simulation before real‑world deployment.
# 8. **Monitor & update**: keep the agent honest and safe.
#
# ---
#
# ### Bottom line
#
# An AI agent is a *complete, goal‑driven system* that can observe, decide, and act—often learning from experience—to accomplish tasks in a dynamic environment. Whether it’s a software bot on your phone or a self‑driving car, the agent framework helps you think about the whole pipeline from perception to action.
# None
